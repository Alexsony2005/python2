# %%
binary = input("Enter binary number: ")
decimal = 0

for digit in binary:
    decimal = decimal * 2 + int(digit)

print("Entered Binary:", binary)
print("Decimal Value =", decimal)
# Out:
# Entered Binary: 1011
# Decimal Value = 11
